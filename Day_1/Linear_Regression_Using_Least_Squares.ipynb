# %% [markdown]
# <a href="https://colab.research.google.com/github/hetpatel1812/Ml-Task/blob/main/Day_1/Linear_Regression_Using_Least_Squares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
x = np.random.rand(100) * 10  # 100 values between 0 and 10
noise = np.random.randn(100) * 2  # random noise
y = 2 * x + 3 + noise  # true relation with noise

# %%
n = len(x)
sum_x = np.sum(x)
sum_y = np.sum(y)
sum_xy = np.sum(x * y)
sum_x2 = np.sum(x ** 2)

# %%
m = (n * sum_xy - sum_x * sum_y) / (n * sum_x2 - sum_x ** 2)
c = (sum_y - m * sum_x) / n

print(f"📈 Slope (m): {m:.2f}")
print(f"📈 Intercept (c): {c:.2f}")
# Out:
# 📈 Slope (m): 1.99
# 📈 Intercept (c): 3.44

# %%
y_pred = m * x + c

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y, label="Data Points", color='skyblue')
plt.plot(x, y_pred, color='red', label="Regression Line")
plt.title("Linear Regression (from scratch)")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
