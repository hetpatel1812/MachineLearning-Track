# %% [markdown]
# <a href="https://colab.research.google.com/github/hetpatel1812/MachineLearning-Track/blob/main/Day_11/Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import accuracy_score,recall_score,precision_score,f1_score

#attual
x=[1,0,1,1,0,1,0]
#gusses
y=[1,0,1,0,0,1,1]
print("accuracy_score",accuracy_score(x,y))
print("recall_score",recall_score(x,y))
print("precision_score",precision_score(x,y))
print("f1_score",f1_score(x,y))
# Out:
# accuracy_score 0.7142857142857143
# recall_score 0.75
# precision_score 0.75
# f1_score 0.75

# %%
from sklearn.metrics import confusion_matrix

#attual
x=[1,0,1,1,0,1,0]
#gusses
y=[1,0,1,0,0,1,1]

cm= confusion_matrix(x,y)
print(cm)
# Out:
# [[2 1]
#  [1 3]]
