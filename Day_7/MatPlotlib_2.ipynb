# %% [markdown]
# <a href="https://colab.research.google.com/github/hetpatel1812/MachineLearning-Track/blob/main/Day_7/MatPlotlib_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#plt.subplot(nrows,ncols,index)
import matplotlib.pyplot as plt
x=[1,2,3,4]
y=[10,15,20,25]
plt.subplot(1,2,1)  #1st row,2nd colm, 1st index
plt.plot(x,y)
plt.title('Line Plot')

plt.subplot(1,2,2)   #1st row,2nd colm, 2st index
plt.bar(x,y)
plt.title('Bar Plot')
plt.tight_layout()
plt.show()

# %%
#fig,ax=plt.subplots(nrows,ncolms,figsize=(width,hight))
fig,ax=plt.subplots(1,2,figsize=(12,4))
x=[1,2,3,4]
y=[10,15,20,25]

ax[0].plot(x,y,color="blue")
ax[0].set_title('Line Plot')

ax[1].bar(x,y,color="lightgreen")
ax[1].set_title('Bar Plot')
fig.suptitle("comparison of line and bar chart")
plt.tight_layout()
plt.show()
