# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = {
    'Age': [25, 30, 35, 40, 45],
    'Income': [30000, 40000, 50000, 60000, 70000],
    'Spending Score': [60, 70, 80, 90, 100],
    'Savings': [5000, 10000, 15000, 20000, 25000]
}

df = pd.DataFrame(data)

Scaler = StandardScaler()
scaled_data = Scaler.fit_transform(df)

pca  =PCA(n_components=2)
pca_result = pca.fit_transform(scaled_data)

pca_df = pd.DataFrame(pca_result,columns=['PCA1','PCA2'])
explained_variance = pca.explained_variance_ratio_
print("Variance captured by each PCA component:")
print(np.round(explained_variance*100,2))
plt.figure(figsize=(8,6))
plt.xlabel('PCA1')
plt.ylabel('PCA2')
plt.title('PCA Visualization')
plt.grid()
plt.scatter(pca_df['PCA1'], pca_df['PCA2'], color='blue')
plt.show()
print(pca_df)
# Out:
# Variance captured by each PCA component:
# [100.   0.]
#            PCA1          PCA2
# 0 -2.828427e+00 -1.824020e-16
# 1 -1.414214e+00  6.080068e-17
# 2  4.440892e-17 -2.625059e-17
# 3  1.414214e+00 -6.080068e-17
# 4  2.828427e+00 -1.216014e-16
